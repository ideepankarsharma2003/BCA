# %%
# import libraries
import pandas as pd
import numpy as np

# %%
## data Cleaning 
# dataset is stored in varialbe data
data  = pd.read_csv("austin_weather.csv")

# %%
# print the data
data
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
# droping the unnessery values/columns
data = data.drop(['Events','Date','SeaLevelPressureAvgInches','SeaLevelPressureLowInches','SeaLevelPressureHighInches'],axis=1)

# %%
data.sample(30)
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 979          93        84        75            75           73           71
# 472          87        78        68            67           65           62
# 354          66        57        47            57           50           45
# 936         101        89        77            74           73           71
# 834          79        62        44            45           41           39
# 463          84        71        57            60           56           50
# 370          74        64        53            63           57           48
# 1298        101        89        77            73           69           58
# 11           69        54        39            51           42           30
# 763          57        44        31            32           30           27
# 1059         82        69        56            62           58           55
# ...

# %%
data.shape
# Out:
# (1319, 16)

# %%
# removing the unNumerical values 
data = data.replace('T',0.0)
data = data.replace('-',0.0)

# %%
data.sample(30)
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 170          86        77        68            75           71           66
# 866          89        74        59            56           53           50
# 284          92        84        76            73           70           63
# 1185         85        75        64            65           60           53
# 1315        105        91        76            71           64           55
# 715          70        57        44            51           46           42
# 408          49        41        33            30           24           19
# 849          75        69        63            68           65           63
# 728          66        51        36            48           40           32
# 975          91        83        75            77           74           70
# 587         102        90        78            70           68           62
# ...

# %%
# data is now preproccsed , finally save the data 
data.to_csv("austin_final.csv")

# %%
## start of next step that is linear model
# import libraries for the model

import sklearn as sk
from sklearn.linear_model import LinearRegression
import matplotlib as plt

# %%
## read the cleanes data
data  = pd.read_csv("austin_final.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0           0         74        60        45           67.0          49.0
# 1           1         56        48        39           43.0          36.0
# 2           2         58        45        32           31.0          27.0
# 3           3         61        46        31           36.0          28.0
# 4           4         58        50        41           44.0          40.0
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0          43.0                 93.0                75.0                57.0
# 1          28.0                 93.0                68.0                43.0
# 2          23.0                 76.0                52.0                27.0
# 3          21.0                 89.0                56.0                22.0
# 4          36.0                 86.0                71.0                56.0
#
# ...

# %%
# store all the feature/indem=pendent variable to x and lables to y
X = data.drop(['PrecipitationSumInches'],axis=1)
# y will serve as labels
y = data['PrecipitationSumInches']

# %%
X.shape
# Out:
# (1319, 16)

# %%
y.shape
# Out:
# (1319,)

# %%
# observe a random day by plotting a graph
day_index = 776
days = [i for i in range (y.size)]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# reshaping the values of y into 1d column matrix
y = y.values.reshape(-1,1)

# %%
# initilize the Linear Regression Classifier
clf = LinearRegression()

# %%
#Train the classifir with an input data
clf.fit(X,y)
# Out:
# LinearRegression()

# %%
# give a sample input to test our model
inp = np.array([[74], [60], [45], [67], [49], [43], [33], [45],[57], [29.68], [10], [7], [2], [0], [20], [4], [31]])
inp = inp.reshape(1,-1)
inp.shape
# Out:
# (1, 17)

# %%
clf.predict(inp)
# Out:
# c:\Users\deepa\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Deepankar\06_semester\temp\kapil\model.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Deepankar/06_semester/temp/kapil/model.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> clf.predict(inp)
#
# File c:\Users\deepa\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# ...

# %%
np.array([inp[0][:-1]])
# Out:
# array([[74.  , 60.  , 45.  , 67.  , 49.  , 43.  , 33.  , 45.  , 57.  ,
#         29.68, 10.  ,  7.  ,  2.  ,  0.  , 20.  ,  4.  ]])

# %%
clf.predict(np.array([inp[0][:-1]]))
# Out:
# c:\Users\deepa\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[-0.40395686]])
